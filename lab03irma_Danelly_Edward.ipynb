# %% [markdown]
# <a href="https://colab.research.google.com/github/ucsd-cse-spis-2023/spis23-lab03-Danelly-Edward/blob/main/lab03irma_Danelly_Edward.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ColabTurtlePlus
# Out:
# Collecting ColabTurtlePlus
#   Downloading ColabTurtlePlus-2.0.1-py3-none-any.whl (31 kB)
# Installing collected packages: ColabTurtlePlus
# Successfully installed ColabTurtlePlus-2.0.1

# %%
# !wget https://raw.githubusercontent.com/ucsd-cse-spis-2023/lab03starter/main/images/atlantic-basin.gif -O /content/atlantic-basin.gif
# !wget https://raw.githubusercontent.com/ucsd-cse-spis-2023/lab03starter/main/images/hurricane.gif -O /content/hurricane.gif
# !mkdir /content/data/
# !wget https://raw.githubusercontent.com/ucsd-cse-spis-2023/lab03starter/main/data/cindy.csv -O /content/data/cindy.csv
# !wget https://raw.githubusercontent.com/ucsd-cse-spis-2023/lab03starter/main/data/don.csv -O /content/data/don.csv
# !wget https://raw.githubusercontent.com/ucsd-cse-spis-2023/lab03starter/main/data/emily.csv -O /content/data/emily.csv
# !wget https://raw.githubusercontent.com/ucsd-cse-spis-2023/lab03starter/main/data/franklin.csv -O /content/data/franklin.csv
# !wget https://raw.githubusercontent.com/ucsd-cse-spis-2023/lab03starter/main/data/gert.csv -O /content/data/gert.csv
# !wget https://raw.githubusercontent.com/ucsd-cse-spis-2023/lab03starter/main/data/harvey.csv -O /content/data/harvey.csv
# !wget https://raw.githubusercontent.com/ucsd-cse-spis-2023/lab03starter/main/data/irma.csv -O /content/data/irma.csv
# !wget https://raw.githubusercontent.com/ucsd-cse-spis-2023/lab03starter/main/data/jose.csv -O /content/data/jose.csv
# !wget https://raw.githubusercontent.com/ucsd-cse-spis-2023/lab03starter/main/data/katia.csv -O /content/data/katia.csv
# !wget https://raw.githubusercontent.com/ucsd-cse-spis-2023/lab03starter/main/data/lee.csv -O /content/data/lee.csv
# !wget https://raw.githubusercontent.com/ucsd-cse-spis-2023/lab03starter/main/data/maria.csv -O /content/data/maria.csv
# !wget https://raw.githubusercontent.com/ucsd-cse-spis-2023/lab03starter/main/data/nate.csv -O /content/data/nate.csv
# !wget https://raw.githubusercontent.com/ucsd-cse-spis-2023/lab03starter/main/data/ophelia.csv -O /content/data/ophelia.csv
# Out:
# --2023-08-15 02:04:45--  https://raw.githubusercontent.com/ucsd-cse-spis-2023/lab03starter/main/images/atlantic-basin.gif
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 100608 (98K) [image/gif]
# Saving to: ‘/content/atlantic-basin.gif’
#
# /content/atlantic-b 100%[===================>]  98.25K  --.-KB/s    in 0.01s
#
# 2023-08-15 02:04:45 (6.56 MB/s) - ‘/content/atlantic-basin.gif’ saved [100608/100608]
#
# --2023-08-15 02:04:45--  https://raw.githubusercontent.com/ucsd-cse-spis-2023/lab03starter/main/images/hurricane.gif
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2060 (2.0K) [image/gif]
# Saving to: ‘/content/hurricane.gif’
#
# /content/hurricane. 100%[===================>]   2.01K  --.-KB/s    in 0s
#
# 2023-08-15 02:04:45 (28.6 MB/s) - ‘/content/hurricane.gif’ saved [2060/2060]
#
# --2023-08-15 02:04:45--  https://raw.githubusercontent.com/ucsd-cse-spis-2023/lab03starter/main/data/cindy.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1092 (1.1K) [text/plain]
# Saving to: ‘/content/data/cindy.csv’
#
# /content/data/cindy 100%[===================>]   1.07K  --.-KB/s    in 0s
#
# 2023-08-15 02:04:46 (60.3 MB/s) - ‘/content/data/cindy.csv’ saved [1092/1092]
#
# --2023-08-15 02:04:46--  https://raw.githubusercontent.com/ucsd-cse-spis-2023/lab03starter/main/data/don.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 427 [text/plain]
# Saving to: ‘/content/data/don.csv’
#
# /content/data/don.c 100%[===================>]     427  --.-KB/s    in 0s
#
# 2023-08-15 02:04:46 (12.8 MB/s) - ‘/content/data/don.csv’ saved [427/427]
#
# --2023-08-15 02:04:46--  https://raw.githubusercontent.com/ucsd-cse-spis-2023/lab03starter/main/data/emily.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 422 [text/plain]
# Saving to: ‘/content/data/emily.csv’
#
# /content/data/emily 100%[===================>]     422  --.-KB/s    in 0s
#
# 2023-08-15 02:04:46 (40.8 MB/s) - ‘/content/data/emily.csv’ saved [422/422]
#
# --2023-08-15 02:04:46--  https://raw.githubusercontent.com/ucsd-cse-spis-2023/lab03starter/main/data/franklin.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1135 (1.1K) [text/plain]
# Saving to: ‘/content/data/franklin.csv’
#
# /content/data/frank 100%[===================>]   1.11K  --.-KB/s    in 0s
#
# 2023-08-15 02:04:46 (91.1 MB/s) - ‘/content/data/franklin.csv’ saved [1135/1135]
#
# --2023-08-15 02:04:46--  https://raw.githubusercontent.com/ucsd-cse-spis-2023/lab03starter/main/data/gert.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 741 [text/plain]
# Saving to: ‘/content/data/gert.csv’
#
# /content/data/gert. 100%[===================>]     741  --.-KB/s    in 0s
#
# 2023-08-15 02:04:46 (60.8 MB/s) - ‘/content/data/gert.csv’ saved [741/741]
#
# --2023-08-15 02:04:46--  https://raw.githubusercontent.com/ucsd-cse-spis-2023/lab03starter/main/data/harvey.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4010 (3.9K) [text/plain]
# Saving to: ‘/content/data/harvey.csv’
#
# /content/data/harve 100%[===================>]   3.92K  --.-KB/s    in 0s
#
# 2023-08-15 02:04:47 (47.7 MB/s) - ‘/content/data/harvey.csv’ saved [4010/4010]
#
# --2023-08-15 02:04:47--  https://raw.githubusercontent.com/ucsd-cse-spis-2023/lab03starter/main/data/irma.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4620 (4.5K) [text/plain]
# Saving to: ‘/content/data/irma.csv’
#
# /content/data/irma. 100%[===================>]   4.51K  --.-KB/s    in 0s
#
# 2023-08-15 02:04:47 (55.5 MB/s) - ‘/content/data/irma.csv’ saved [4620/4620]
#
# --2023-08-15 02:04:47--  https://raw.githubusercontent.com/ucsd-cse-spis-2023/lab03starter/main/data/jose.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3677 (3.6K) [text/plain]
# Saving to: ‘/content/data/jose.csv’
#
# /content/data/jose. 100%[===================>]   3.59K  --.-KB/s    in 0s
#
# 2023-08-15 02:04:47 (47.3 MB/s) - ‘/content/data/jose.csv’ saved [3677/3677]
#
# --2023-08-15 02:04:47--  https://raw.githubusercontent.com/ucsd-cse-spis-2023/lab03starter/main/data/katia.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 960 [text/plain]
# Saving to: ‘/content/data/katia.csv’
#
# /content/data/katia 100%[===================>]     960  --.-KB/s    in 0s
#
# 2023-08-15 02:04:47 (99.7 MB/s) - ‘/content/data/katia.csv’ saved [960/960]
#
# --2023-08-15 02:04:47--  https://raw.githubusercontent.com/ucsd-cse-spis-2023/lab03starter/main/data/lee.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1779 (1.7K) [text/plain]
# Saving to: ‘/content/data/lee.csv’
#
# /content/data/lee.c 100%[===================>]   1.74K  --.-KB/s    in 0s
#
# 2023-08-15 02:04:47 (27.6 MB/s) - ‘/content/data/lee.csv’ saved [1779/1779]
#
# --2023-08-15 02:04:48--  https://raw.githubusercontent.com/ucsd-cse-spis-2023/lab03starter/main/data/maria.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4306 (4.2K) [text/plain]
# Saving to: ‘/content/data/maria.csv’
#
# /content/data/maria 100%[===================>]   4.21K  --.-KB/s    in 0s
#
# 2023-08-15 02:04:48 (43.3 MB/s) - ‘/content/data/maria.csv’ saved [4306/4306]
#
# --2023-08-15 02:04:48--  https://raw.githubusercontent.com/ucsd-cse-spis-2023/lab03starter/main/data/nate.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1371 (1.3K) [text/plain]
# Saving to: ‘/content/data/nate.csv’
#
# /content/data/nate. 100%[===================>]   1.34K  --.-KB/s    in 0s
#
# 2023-08-15 02:04:48 (143 MB/s) - ‘/content/data/nate.csv’ saved [1371/1371]
#
# --2023-08-15 02:04:48--  https://raw.githubusercontent.com/ucsd-cse-spis-2023/lab03starter/main/data/ophelia.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 562 [text/plain]
# Saving to: ‘/content/data/ophelia.csv’
#
# /content/data/ophel 100%[===================>]     562  --.-KB/s    in 0s
#
# 2023-08-15 02:04:48 (45.8 MB/s) - ‘/content/data/ophelia.csv’ saved [562/562]

# %%
from ColabTurtlePlus.Turtle import *
from ColabTurtlePlus.Turtle import _Screen
import csv
# Out:
# Put clearscreen() as the first line in a cell (after the import command) to re-run turtle commands in the cell

# %%
MY_SVG_TEMPLATE = """
      <svg width="{window_width}" height="{window_height}">
        <image width="100%" height="100%" href="https://raw.githubusercontent.com/ucsd-cse-spis-2023/lab03starter/main/images/atlantic-basin.gif"/>
        {drawlines}
        {stampsB}
        {lines}
        {dots}
        {stampsT}
        {turtle}
      </svg>
    """

TURTLE_HURRICANE_SVG_TEMPLATE = """<g id="turtle2" visibility="{visibility}" transform="rotate({degrees},{rotation_x},{rotation_y}) translate({turtle_x}, {turtle_y})">
    <image width="40" height="40" href="https://raw.githubusercontent.com/ucsd-cse-spis-2023/lab03starter/main/images/hurricane.gif"/>
    </g>"""

VALID_TURTLE_SHAPES = ('turtle', 'ring', 'classic', 'arrow', 'square', 'triangle', 'circle', 'turtle2', 'hurricane', 'blank')

# %%
def AtlanticScreen():
    """Return the singleton screen object.
    If none exists at the moment, create a new one and return it,
    else return the existing one."""
    if Turtle._screen is None:
        Turtle._screen = _AtlanticScreen()
    return Turtle._screen

class _AtlanticScreen(_Screen):

    def __init__(self):
        super().__init__()
        self.window_size = (964, 600)
        # imitating setworldcoordinates(-90, 0, -17.66, 45):
        self.xmin = -90
        self.ymin =  0
        self.xmax = -17.66
        self.ymax = 45
        self.xscale = self.window_size[0]/(self.xmax-self.xmin)
        self.yscale = self.window_size[1]/(self.ymax-self.ymin)
        self._mode = "world"

    def clear(self):
        super().clear()
        Turtle._screen = AtlanticScreen()

    def _generateOneSvgTurtle(self,turtle):
        if turtle.turtle_shape == 'hurricane':
            turtle_x = turtle.turtle_pos[0] - 20
            turtle_y = turtle.turtle_pos[1] - 20
            if self._mode == "standard":
                degrees = turtle.turtle_degree - turtle.tilt_angle - 90
            elif self._mode == "world":
                degrees = turtle.turtle_orient - turtle.tilt_angle - 90
            else:
                degrees = turtle.turtle_degree + turtle.tilt_angle - 90
            svg = turtle.shapeDict[turtle.turtle_shape].format(
                           turtle_color=turtle.fill_color,
                           pcolor=turtle.pen_color,
                           turtle_x=turtle_x,
                           turtle_y=turtle_y,
                           visibility='visible',
                           degrees=degrees,
                           sx=turtle.stretchfactor[0],
                           sy=turtle.stretchfactor[1],
                           sk=turtle.shear_factor,
                           rx=10*turtle.stretchfactor[0],
                           ry=10*turtle.stretchfactor[1],
                           cy=-(10*turtle.stretchfactor[1]+4),
                           pw = turtle.outline_width,
                           rotation_x=turtle.turtle_pos[0],
                           rotation_y=turtle.turtle_pos[1])
        else:
          svg = super()._generateOneSvgTurtle(turtle)
        return svg

    def _generateSvgDrawing(self):
        return MY_SVG_TEMPLATE.format(window_width=self.window_size[0],
                               window_height=self.window_size[1],
                               backcolor=self.background_color,
                               fill=self._generateSvgFill(),
                               lines=self._generateSvgLines(),
                               dots=self._generateSvgDots(),
                               stampsB=self._generateSvgStampsB(),
                               stampsT=self._generateSvgStampsT(),
                               turtle=self._generateTurtlesSvgDrawing(),
                               drawlines=self._svg_drawlines_string,
                               kolor=self.border_color)

class MyRawTurtle(RawTurtle):

    def __init__(self, window=None):
        super().__init__(window)
        self.shapeDict["hurricane"] = TURTLE_HURRICANE_SVG_TEMPLATE

class HurricaneTurtle(MyRawTurtle):
    _pen = None
    _screen = None

    def __init__(self):
        if Turtle._screen is None:
            Turtle._screen = MyScreen()
        MyRawTurtle.__init__(self, Turtle._screen)

    def shape(self, name=None):
        if name is None:
            return self.turtle_shape
        elif name.lower() not in VALID_TURTLE_SHAPES:
            raise ValueError('Shape is invalid. Valid options are: ' + str(VALID_TURTLE_SHAPES))
        self.turtle_shape = name.lower()
        self.screen._updateDrawing(turtle=self)

# %%
def irma_setup():
    """Creates the Turtle and the Screen with the map background
       and coordinate system set to match latitude and longitude.

       :return: a tuple containing the Turtle and the Screen

       DO NOT CHANGE THE CODE IN THIS FUNCTION!
    """
    scr = AtlanticScreen()
    scr.clear()
    t = HurricaneTurtle()
    t.speed(7)
    t.shape("hurricane")

    return (t, scr)

# %%
def irma():
    """Animates the path of hurricane Irma (2017)
    """
    # Do not change this line
    # t is the turtle, and you will not need the other variable
    (t, scr) = irma_setup()

    hurricaneFile = "/content/data/irma.csv"
    # The line below is a little magical. It opens the file,
    # with awareness of any errors that might occur.
    with open(hurricaneFile, 'r') as csvfile:
        # This line gives you an "iterator" you can use to get each line
        # in the file.
        pointreader = csv.reader(csvfile)

        # You'll need to add some code here, before the loop
        # One thing you'll need to figure out how to do is to
        # skip the first line of the file (which is the header).
        # You might use a boolean variable, or you can
        # look into Python's built-in next function
        #(https://docs.python.org/3/library/functions.html#next)
        # pointreader is an iterator

        t.speed(10)

        for row in pointreader:
            # row is a list representing each line in the csv file
            # Each comma separated element is in its own index position
            # This code just prints out the date and time elements of each
            # row in the file.
            # Make sure you understand what is happening here.
            # Then, you'll need to change this code
            # print("Date:", row[0], "Time:", row[1], "Lat:", row[2], "Lon:", row[3], "Wind", row[4], "Pressure", row[5])


            if row[0] != "Date":        # skip the header
              wind = float(row[4])      # change wind into a float

              t.setpos(float(row[3]), float(row[2]))          # change lon/lat into a float and insert as x/y

              if wind < 74:                                   # change the characteristics of the turtle depending on the speed of the wind
                t.pencolor(255,255,255)
                t.pensize(2)

              if wind >= 74 and wind <= 95:                   # class 1 hurricane
                t.pencolor(0,0,255)
                t.pensize(4)
                t.write("1")

              if wind >= 96 and wind <= 110:                  # class 2 hurricane
                t.pencolor(0, 128, 0)
                t.pensize(6)
                t.write("2")

              if wind >= 111 and wind <= 129:                 # class 3 hurricane
                t.pencolor(255, 252, 64)
                t.pensize(8)
                t.write("3")

              if wind >= 130 and wind <= 156:                 # class 4 hurricane
                t.pencolor(230, 110, 32)
                t.pensize(10)
                t.write("4")

              if wind >= 157:                                 # class 5 hurricane
                t.pencolor(136, 8, 8)
                t.pensize(12)
                t.write("5")

# %%
irma()
# Out:
#       <svg width="964" height="600">
#         <image width="100%" height="100%" href="https://raw.githubusercontent.com/ucsd-cse-spis-2023/lab03starter/main/images/atlantic-basin.gif"/>
#
#
#         <line x1="1199.336466685098" y1="600.0" x2="795.56" y2="381.333" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="795.56" y1="381.333" x2="783.566" y2="381.333" stroke-linecap="round" style="stroke:rgb(255,255,255);stroke-width:2" /><line x1="783.566" y1="381.333" x2="770.241" y2="381.333" stroke-linecap="round" style="stroke:rgb(255,255,255);stroke-width:2" /><line x1="770.241" y1="381.333" x2="760.912" y2="380.0" stroke-linecap="round" style="stroke:rgb(255,255,255);stroke-width:2" /><line x1="760.912" y1="380.0" x2="748.919" y2="374.667" stroke-linecap="round" style="stroke:rgb(255,255,255);stroke-width:2" /><text x="748.919" y="374.667" fill="rgb(0,128,0)" text-anchor="start" style="font-size:12px;font-family:'Arial';">2</text><line x1="748.919" y1="374.667" x2="735.593" y2="369.333" stroke-linecap="round" style="stroke:rgb(0,128,0);stroke-width:6" /><text x="735.593" y="369.333" fill="rgb(255,252,64)" text-anchor="start" style="font-size:12px;font-family:'Arial';">3</text><line x1="735.593" y1="369.333" x2="724.932" y2="362.667" stroke-linecap="round" style="stroke:rgb(255,252,64);stroke-width:8" /><text x="724.932" y="362.667" fill="rgb(255,252,64)" text-anchor="start" style="font-size:12px;font-family:'Arial';">3</text><line x1="724.932" y1="362.667" x2="712.939" y2="357.333" stroke-linecap="round" style="stroke:rgb(255,252,64);stroke-width:8" /><text x="712.939" y="357.333" fill="rgb(255,252,64)" text-anchor="start" style="font-size:12px;font-family:'Arial';">3</text><line x1="712.939" y1="357.333" x2="695.615" y2="353.333" stroke-linecap="round" style="stroke:rgb(255,252,64);stroke-width:8" /><text x="695.615" y="353.333" fill="rgb(0,128,0)" text-anchor="start" style="font-size:12px;font-family:'Arial';">2</text><line x1="695.615" y1="353.333" x2="678.291" y2="349.333" stroke-linecap="round" style="stroke:rgb(0,128,0);stroke-width:6" /><text x="678.291" y="349.333" fill="rgb(255,252,64)" text-anchor="start" style="font-size:12px;font-family:'Arial';">3</text><line x1="678.291" y1="349.333" x2="659.635" y2="345.333" stroke-linecap="round" style="stroke:rgb(255,252,64);stroke-width:8" /><text x="659.635" y="345.333" fill="rgb(255,252,64)" text-anchor="start" style="font-size:12px;font-family:'Arial';">3</text><line x1="659.635" y1="345.333" x2="642.311" y2="346.667" stroke-linecap="round" style="stroke:rgb(255,252,64);stroke-width:8" /><text x="642.311" y="346.667" fill="rgb(0,128,0)" text-anchor="start" style="font-size:12px;font-family:'Arial';">2</text><line x1="642.311" y1="346.667" x2="622.322" y2="349.333" stroke-linecap="round" style="stroke:rgb(0,128,0);stroke-width:6" /><text x="622.322" y="349.333" fill="rgb(0,128,0)" text-anchor="start" style="font-size:12px;font-family:'Arial';">2</text><line x1="622.322" y1="349.333" x2="604.999" y2="353.333" stroke-linecap="round" style="stroke:rgb(0,128,0);stroke-width:6" /><text x="604.999" y="353.333" fill="rgb(0,128,0)" text-anchor="start" style="font-size:12px;font-family:'Arial';">2</text><line x1="604.999" y1="353.333" x2="583.677" y2="356.0" stroke-linecap="round" style="stroke:rgb(0,128,0);stroke-width:6" /><text x="583.677" y="356.0" fill="rgb(0,128,0)" text-anchor="start" style="font-size:12px;font-family:'Arial';">2</text><line x1="583.677" y1="356.0" x2="566.353" y2="360.0" stroke-linecap="round" style="stroke:rgb(0,128,0);stroke-width:6" /><text x="566.353" y="360.0" fill="rgb(255,252,64)" text-anchor="start" style="font-size:12px;font-family:'Arial';">3</text><line x1="566.353" y1="360.0" x2="554.36" y2="364.0" stroke-linecap="round" style="stroke:rgb(255,252,64);stroke-width:8" /><text x="554.36" y="364.0" fill="rgb(255,252,64)" text-anchor="start" style="font-size:12px;font-family:'Arial';">3</text><line x1="554.36" y1="364.0" x2="535.704" y2="365.333" stroke-linecap="round" style="stroke:rgb(255,252,64);stroke-width:8" /><text x="535.704" y="365.333" fill="rgb(255,252,64)" text-anchor="start" style="font-size:12px;font-family ...
